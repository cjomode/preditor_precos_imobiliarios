# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Recife_Dados_imoveis.csv')

# %%
df
# Out:
#     Recife Imóveis residenciais – Venda       Unnamed: 2  \
# 0      NaN                Número-Índice  Var. mensal (%)
# 1     Data                        Total            Total
# 2   jan/20                        195,5           +0,00%
# 3   fev/20                        194,9           -0,32%
# 4   mar/20                        193,8           -0,55%
# ..     ...                          ...              ...
# 62  jan/25                        253,1           -0,18%
# 63  fev/25                        253,7           +0,25%
# 64  mar/25                        254,1           +0,16%
# 65  abr/25                        254,7           +0,21%
# 66  mai/25                        256,1           +0,55%
#
#               Unnamed: 3           Unnamed: 4 Imóveis residenciais-Locação  \
# 0   Var. em 12 meses (%)  Preço médio (R$/m²)                Número-Índice
# 1                  Total                Total                        Total
# ...

# %%
df.describe()
# Out:
#        Recife Imóveis residenciais – Venda Unnamed: 2 Unnamed: 3  \
# count      66                           67         67         67
# unique     66                           64         54         65
# top      Data                        194,9     +0,59%     +6,36%
# freq        1                            3          3          2
#
#                  Unnamed: 4 Imóveis residenciais-Locação Unnamed: 6  \
# count                    67                           66         66
# unique                   67                           63         56
# top     Preço médio (R$/m²)                        122,6     +0,70%
# freq                      1                            3          2
#
#        Unnamed: 7 Unnamed: 8  \
# count          66         66
# unique         65         61
# top       +15,54%       31,8
# freq            2          3
#
#        Imóveis residenciais-Rentabilidade do aluguel (rental yield)
# count                                                  66
# ...

# %%
df.isnull().any()
# Out:
# Recife                                                           True
# Imóveis residenciais – Venda                                    False
# Unnamed: 2                                                      False
# Unnamed: 3                                                      False
# Unnamed: 4                                                      False
# Imóveis residenciais-Locação                                     True
# Unnamed: 6                                                       True
# Unnamed: 7                                                       True
# Unnamed: 8                                                       True
# Imóveis residenciais-Rentabilidade do aluguel (rental yield)     True
# dtype: bool

# %%
df.dtypes
# Out:
# Recife                                                          object
# Imóveis residenciais – Venda                                    object
# Unnamed: 2                                                      object
# Unnamed: 3                                                      object
# Unnamed: 4                                                      object
# Imóveis residenciais-Locação                                    object
# Unnamed: 6                                                      object
# Unnamed: 7                                                      object
# Unnamed: 8                                                      object
# Imóveis residenciais-Rentabilidade do aluguel (rental yield)    object
# dtype: object
